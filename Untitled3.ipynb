# %%
print('Hello World!')
# Out:
# Hello World!

# %%
num = int(input("Enter the Number :"))
if(num%2==0):
  print("It is a even number")
else:
  print("It is odd number")
# Out:
# Enter the Number :5
# It is odd number

# %%
num = 5
f=1
for i in range (2,num+1):
  f = f*i
print('Factorial of number is :',f)
# Out:
# Factorial of number is : 120

# %%
num = 5
sum = 0
for i in range (1,num+1):
  sum=sum+i
print("Sum of Natural Numbers :",sum)
# Out:
# Sum of Natural Numbers : 15

# %%
# It is Comment .

# %%
1 + 1
2 * 3.5
# Out:
# 7.0

# %%
print(1 + 1)
print(2 * 3.5)
# Out:
# 2
# 7.0

# %%
print('1 + 1 is', 1 + 1)
# this is a comment, Python won't try to execute it
print('All done!')
# Out:
# 1 + 1 is 2
# All done!

# %%
first_result = 1 + 1
final_result = first_result * 3.5

print(final_result)
# Out:
# 7.0

# %%
sum =2+2
sum = sum*5
print(sum)
# Out:
# 20

# %%
my_name = 'Dylan'
my_age = 28
my_favorite_number = 2.718
has_dog = True

print('My name is', my_name)
print('My age is', my_age)
print('My favorite number is', my_favorite_number)
print('I own a dog:', has_dog)
# Out:
# My name is Dylan
# My age is 28
# My favorite number is 2.718
# I own a dog: True

# %%
print(type(my_name))
print(type(my_age))
print(type(my_favorite_number))
print(type(has_dog))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
def square(number):
    return number**2
print(square(2))
print(square(6))
# Out:
# 4
# 36

# %%
# we can store function output in variables
squared = square(5.5)

print(squared)

my_number = 6
# we can also use variables as function input
print(square(my_number))
# Out:
# 30.25
# 36

# %%
print(square('banana'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-ae2e519c2d8c> in <module>()
# ----> 1 print(square('banana'))
#
# <ipython-input-47-d647e14d51f1> in square(number)
#       1 def square(number):
# ----> 2     return number**2
#       3 print(square(2))
#       4 print(square(6))
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
def cube(number):
  return number**3
print(cube(3))
print(cube(9))
# Out:
# 27
# 729
